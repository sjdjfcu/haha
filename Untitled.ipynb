# %%
par(mfrow=c(2,2))
x<-seq(-2,2,0.1)
y=sin(x);z=3*cos(x);a=sin(x)*cos(x);b=sin(x)/x
plot(x,y,"l")
plot(x,z,"l")
plot(x,a,"l")
plot(x,b,"l")
# Out:
# plot without title

# %%
class<-read.table("class.txt",sep='\t')
names(class)<-c('name', 'age', 'height', 'weight', 'sex')
attach(class)
par(mfrow=c(2,2))
qqnorm(weight,main="qqnorm",xlab="x",ylab="y")
hist(weight,main="histogram",xlab="x",ylab="y")
boxplot(weight,main="boxplot",xlab="x",ylab="y")
qqplot(height,weight,main="qqplot",xlab="x",ylab="y")
# Out:
# Plot with title “qqplot”

# %%
class<-read.table("class.txt",sep='\t')
names(class)<-c('name', 'age', 'height', 'weight', 'sex')
attach(class)
lm.sol<-lm(weight~height,class);plot(height,weight);lines(height,weight);text(height,weight);abline(lm.sol);title(main="plot")
pairs(class);title(main="pairs")
coplot(weight~height|age);title(main="coplot")
qqnorm(weight);title(main="qqnorm")
qqline(weight);title(main="qqline")
qqplot(height,weight);title(main="qqplot")
hist(age);lines(density(age),col="blue");lines(age, dnorm(age, mean(age), sd(age)), col="red" )
dotchart(height,weight);title(main="dotchart");mtext("height",1,2);mtext("weight",2,2)
# Out:
# Plot with title “plot”
# Plot with title “pairs”
# Plot with title “coplot”
# Plot with title “qqline”
# Plot with title “qqplot”
# Plot with title “Histogram of age”
# Plot with title “dotchart”

# %%
Year=c(2010,2011,2012,2013,2014,2015)
A=c(180,220,270,400,600,650)
B=c(150,210,260,310,400,500)
matplot(Year,A,type="o",pch=15,lty=1,bg="red",col="red",xlab="Year",ylab="Amount of Exports")
matplot(Year,B,type="o",pch=17,lty=2,add=T,bg="blue",col="blue")
legend("topleft", inset=.05, title="Factory", c("A","B"),lty=c(1, 2), pch=c(15, 17), col=c("red", "blue"))
title(main="Factory A vs. Factory B")
# Out:
# Plot with title “Factory A vs. Factory B”
